# %%
import os
import pandas as pd
import polars as pl

# %% [markdown]
# ### Review contents of all `./HFMG/Compressed`
# * 29 Files or parent directories.
# * We are interested only in data having a timestamp.

# %%
struct = {}
path = './HFHS Data/Compressed/'
for root, dirs, files in os.walk(path):
    if root != path: 
        struct[root] = files

struct = dict(sorted(struct.items()))

# %%
assert len(struct) == 29
for k, v in struct.items():
    print(str(len(v)) + '\t' + k)
# Out:
# 1	./HFHS Data/Compressed/Complete ED Provider Notes for 2014 Patients
# 4	./HFHS Data/Compressed/Complete ED Provider Notes for 2015-2016 Patients
# 1	./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS
# 1	./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW
# 1	./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspecified
# 1	./HFHS Data/Compressed/WSU_HASHED_ALL_INPATIENT_ADMIT_DISCHARGE_TIMES
# 1	./HFHS Data/Compressed/WSU_HASHED_ATMO_METRICS_3
# 1	./HFHS Data/Compressed/WSU_HASHED_ATMO_METRICS_4
# 1	./HFHS Data/Compressed/WSU_HASHED_BASE_CSN_SELECT
# 1	./HFHS Data/Compressed/WSU_HASHED_BASE_CSN_SELECT_FirstNonEDDepartment
# 1	./HFHS Data/Compressed/WSU_HASHED_BASE_MRN_SELECT
# 1	./HFHS Data/Compressed/WSU_HASHED_BED_PATIENT_MOVEMENT
# 1	./HFHS Data/Compressed/WSU_HASHED_BED_REQUEST_INFO
# 6	./HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT
# 1	./HFHS Data/Compressed/WSU_HASHED_DX_LIST
# 1	./HFHS Data/Compressed/WSU_HASHED_EVENTS
# 1	./HFHS Data/Compressed/WSU_HASHED_LAB_TEST_INFO
# 1	./HFHS Data/Compressed/WSU_HASHED_MEDICATION_HISTORY
# 1	./HFHS Data/Compressed/WSU_HASHED_MIN_VITALS_TRIAGE
# 3	./HFHS Data/Compressed/WSU_HASHED_MRN_DX_HISTORY_Headers_and_CSV_and_Tab_delim
# 1	./HFHS Data/Compressed/WSU_HASHED_NOTE_ED_Notes_only
# 1	./HFHS Data/Compressed/WSU_HASHED_NOTE_ED_Provider_Notes_only
# 1	./HFHS Data/Compressed/WSU_HASHED_NOTE_ED_other_Notes
# 1	./HFHS Data/Compressed/WSU_HASHED_NOTE_INFO
# 1	./HFHS Data/Compressed/WSU_HASHED_NOTE_INFO_NEW
# 1	./HFHS Data/Compressed/WSU_HASHED_NOTE_INFO_TAB
# 1	./HFHS Data/Compressed/WSU_HASHED_PROVIDER_IN_OUT
# 1	./HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC
# 6	./HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6

# %%
targets = []
for root, files in struct.items():
    for file in sorted(files): 
        if 'note' in root.lower() or 'note' in file.lower():
            print(os.path.join(root, file))
        else: 
            targets.append(os.path.join(root, file))
# Out:
# ./HFHS Data/Compressed/Complete ED Provider Notes for 2014 Patients/2014 ED Provider Notes.txt
# ./HFHS Data/Compressed/Complete ED Provider Notes for 2015-2016 Patients/Provider Notes 2015-01-01 through 2015-06-30.txt
# ./HFHS Data/Compressed/Complete ED Provider Notes for 2015-2016 Patients/Provider Notes 2015-07-01 through 2015-12-31.txt
# ./HFHS Data/Compressed/Complete ED Provider Notes for 2015-2016 Patients/Provider Notes 2016-01-01 through 2016-06-30.txt
# ./HFHS Data/Compressed/Complete ED Provider Notes for 2015-2016 Patients/Provider Notes 2016-07-01 through 2016-12-31.txt
# ./HFHS Data/Compressed/WSU_HASHED_NOTE_ED_Notes_only/WSU_HASHED_NOTE_ED_Notes_only.txt
# ./HFHS Data/Compressed/WSU_HASHED_NOTE_ED_Provider_Notes_only/WSU_HASHED_NOTE_ED_Provider_Notes_only.txt
# ./HFHS Data/Compressed/WSU_HASHED_NOTE_ED_other_Notes/WSU_HASHED_NOTE_ED_other_Notes.txt
# ./HFHS Data/Compressed/WSU_HASHED_NOTE_INFO/WSU_HASHED_NOTE_INFO.csv
# ./HFHS Data/Compressed/WSU_HASHED_NOTE_INFO_NEW/WSU_HASHED_NOTE_INFO_NEW.csv
# ./HFHS Data/Compressed/WSU_HASHED_NOTE_INFO_TAB/WSU_HASHED_NOTE_INFO_TAB.txt

# %%
len(targets)
# Out:
# 33

# %%
targets
# Out:
# ['./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS/WSU_HASHED_ALL_CHIEF_COMPLAINTS.csv',
#  './HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW.csv',
#  './HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspecified/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspecified.csv',
#  './HFHS Data/Compressed/WSU_HASHED_ALL_INPATIENT_ADMIT_DISCHARGE_TIMES/WSU_HASHED_ALL_INPATIENT_ADMIT_DISCHARGE_TIMES.csv',
#  './HFHS Data/Compressed/WSU_HASHED_ATMO_METRICS_3/WSU_HASHED_ATMO_METRICS_3.csv',
#  './HFHS Data/Compressed/WSU_HASHED_ATMO_METRICS_4/WSU_HASHED_ATMO_METRICS_4.csv',
#  './HFHS Data/Compressed/WSU_HASHED_BASE_CSN_SELECT/WSU_HASHED_BASE_CSN_SELECT.csv',
#  './HFHS Data/Compressed/WSU_HASHED_BASE_CSN_SELECT_FirstNonEDDepartment/WSU_HASHED_BASE_CSN_SELECT_FirstNonEDDepartment.csv',
#  './HFHS Data/Compressed/WSU_HASHED_BASE_MRN_SELECT/WSU_HASHED_BASE_MRN_SELECT.csv',
#  './HFHS Data/Compressed/WSU_HASHED_BED_PATIENT_MOVEMENT/WSU_HASHED_BED_PATIENT_MOVEMENT.csv',
#  './HFHS Data/Compressed/WSU_HASHED_BED_REQUEST_INFO/WSU_HASHED_BED_REQUEST_INFO.csv',
#  './HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT/WSU_HASHED_CSN_MRN_All_patient_movement_DATASET1.csv',
#  './HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT/WSU_HASHED_CSN_MRN_All_patient_movement_DATASET2.csv',
#  './HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT/WSU_HASHED_CSN_MRN_FirstNonEDDepartment DATASET1.csv',
#  './HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT/WSU_HASHED_CSN_MRN_FirstNonEDDepartment_DATASET2.csv',
#  './HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT/WSU_HASHED_CSN_MRN_FirstNonEDDepartment_headers.csv',
#  './HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT/WSU_HASHED_CSN_MRN_PatientMovement_headers.csv',
#  './HFHS Data/Compressed/WSU_HASHED_DX_LIST/WSU_HASHED_DX_LIST.csv',
#  './HFHS Data/Compressed/WSU_HASHED_EVENTS/WSU_HASHED_EVENTS.csv',
#  './HFHS Data/Compressed/WSU_HASHED_LAB_TEST_INFO/WSU_HASHED_LAB_TEST_INFO.csv',
#  './HFHS Data/Compressed/WSU_HASHED_MEDICATION_HISTORY/WSU_HASHED_MEDICATION_HISTORY.csv',
#  './HFHS Data/Compressed/WSU_HASHED_MIN_VITALS_TRIAGE/WSU_HASHED_MIN_VITALS_TRIAGE.csv',
#  './HFHS Data/Compressed/WSU_HASHED_MRN_DX_HISTORY_Headers_and_CSV_and_Tab_delim/WSU_HASHED_MRN_DX_HISTORY.csv',
#  './HFHS Data/Compressed/WSU_HASHED_MRN_DX_HISTORY_Headers_and_CSV_and_Tab_delim/WSU_HASHED_MRN_DX_HISTORY_HEADERS.csv',
#  './HFHS Data/Compressed/WSU_HASHED_MRN_DX_HISTORY_Headers_and_CSV_and_Tab_delim/WSU_HASHED_MRN_DX_HISTORY_tab_delimited.txt',
#  './HFHS Data/Compressed/WSU_HASHED_PROVIDER_IN_OUT/WSU_HASHED_PROVIDER_IN_OUT.csv',
#  './HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC/WSU_HASHED_VITALS_GLUCOSE_ETC.csv',
#  './HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1.csv',
#  './HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6/WSU_HASHED_VITALS_GLUCOSE_ETC_PT2.csv',
#  './HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6/WSU_HASHED_VITALS_GLUCOSE_ETC_PT3.csv',
#  './HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6/WSU_HASHED_VITALS_GLUCOSE_ETC_PT4.csv',
#  './HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6/WSU_HASHED_VITALS_GLUCOSE_ETC_PT5.csv',
#  './HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6/WSU_HASHED_VITALS_GLUCOSE_ETC_PT6.csv']

# %% [markdown]
# Pull out the first three rows of each file and inspect for:
# * presence of headers,
# * presence/position of `CSN_HASH` (visit ID),
# * presence/position of timestamp.

# %%
for i, file in enumerate(targets): 
    print(f'File {i + 1}: {file}\n')
    with open(file) as f:
        [print('\t' + f.readline().strip()) for _ in range(3)]
    print('\n')
# Out:
# File 1: ./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS/WSU_HASHED_ALL_CHIEF_COMPLAINTS.csv
#
# 	﻿CSN_HASH,ChiefComplaint
# 	0x00000F5D77FB3D9F299A327BF784BE4878B53B45B2A4A3AAB20764E6F130B0EA,RASH
# 	0x0000429B06ACE47BEAC568C8A6DD22F83037E7385DB9BBEFC998E6F9CBA79BFE,THREATENED MISCARRIAGE
#
#
# File 2: ./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW.csv
#
# 	﻿0x82CF08E5F226CF14A8667B57966A110E07380D24835DC3BE8596E1FFDEC3994A,SUTURE / STAPLE REMOVAL
# 	0x82CF08E5F226CF14A8667B57966A110E07380D24835DC3BE8596E1FFDEC3994A,EDEMA
# 	0x768947877A3F32D11AFF45F2DCE525704A03C5D530AEFA2A3142656196D12EF3,SUTURE / STAPLE REMOVAL
#
#
# File 3: ./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspecified/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspec
./HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT/WSU_HASHED_CSN_MRN_FirstNonEDDepartment_headers.csv
#
# 	CSN_HASH,MRN_HASH,FirstNonEdDepartment
#
#
#
#
# File 17: ./HFHS Data/Compressed/WSU_HASHED_CSN_MRN_PATIENT_MOVEMENT/WSU_HASHED_CSN_MRN_PatientMovement_headers.csv
#
# 	CSN_HASH,MRN_HASH,Location,Department,Accommodation,bed_id,room_id,BED_LABEL,ROOM_NAME,IN_DTTM,OUT_DTTM,Next_Dept,Next_accommodation,Next_Bed,Next_Room,NAME,Bed_sort_order
#
#
#
#
# File 18: ./HFHS Data/Compressed/WSU_HASHED_DX_LIST/WSU_HASHED_DX_LIST.csv
#
# 	﻿0x2BECA14F105C520DAD9CC626C84BD9E60807A9A5D0F2D8ADC828FE48B4F34FE5,ICD-10,Y93.67,NULL,3,Activity involving basketball
# 	0x374DB224FFE6172EC0FC8FB3EB88268B232B1883FB4F3AE3398AC6A8FDD17D13,ICD-10,R07.89,NULL,3,Other chest pain
# 	0x374DB224FFE6172EC0FC8FB3EB88268B232B1883FB4F3AE3398AC6A8FDD17D13,ICD-10,R22.0,NULL,2,Facial swelling
#
#
# File 19: ./HFHS Data/Compressed/WSU_HASHED_EVENTS/WSU_HASHED_EVENTS.csv
#
# 	CSN_HASH,MRN_HASH,EVENT_ID,LINE,EVENT_TYPE,EVENT_DISPLAY_NAME,EVENT_TIME,EVENT_RECORD_TIME,EVENT_USER_ID,USER_NAME,EVENT_CMT
# 	9CE944F88A3C3F1AE4FF377A7631220E7CFDE30DD1DC9687E5D1AA0AD37DC4FA,6EBF2C5445785D7B0B96FCAA64EA1A2C4BA5E98207E60E65FFD9EE8FE9907307,11858804,18,106004,Imaging Exam Ordered,2014-08-23 06:40:16,2014-08-23 06:40:16,503210,COTARLA, MICHAEL,
# 	9CE944F88A3C3F1AE4FF377A7631220E7CFDE30DD1DC9687E5D1AA0AD37DC4FA,6EBF2C5445785D7B0B96FCAA64EA1A2C4BA5E98207E60E65FFD9EE8FE9907307,11858804,19,30025,Lab Resulted,2014-08-23 06:47:28,2014-08-23 06:47:28,EDILABIM,LABORATORY MEDICINE, PATHOLOGY AND,(Final result) PT/INR/PTT
#
#
# File 20: ./HFHS Data/Compressed/WSU_HASHED_LAB_TEST_INFO/WSU_HASHED_LAB_TEST_INFO.csv
#
# 	﻿0x6866B1E321722786E0C3CFBAF02E276B733967073B9099CC5C0D81857D37694D,96885439,Troponin I now, then in 3 hours,64647,SUNQUEST,12,41,NULL,2014-08-15 18:49:00.000,Final result,High,0.11,NULL,NULL,ng/mL,NULL,2014-08-15 17:10:00.000,2014-08-15 17:09:00.000,2014-08-15 18:49:00.000,H123700,VOELTZ, MICHELE,LAB747
# 	0x6866B1E321722786E0C3CFBAF02E276B733967073B9099CC5C0D81857D37694D,96885440,Troponin I now, then in 3 hours,64647,SUNQUEST,12,41,NULL,2014-08-15 21:59:00.000,Final result,High Panic,7.73,NULL,NULL,ng/mL,NULL,2014-08-15 17:10:00.000,2014-08-15 20:09:00.000,2014-08-15 21:59:00.000,H123700,VOELTZ, MICHELE,LAB747
# 	0x6866B1E321722786E0C3CFBAF02E276B733967073B9099CC5C0D81857D37694D,96
FHS Data/Compressed/WSU_HASHED_MRN_DX_HISTORY_Headers_and_CSV_and_Tab_delim/WSU_HASHED_MRN_DX_HISTORY.csv
#
# 	﻿CSN_HASH,MRN_HASH,ARRIVAL,DISCHARGE,DX_LINE,ICD_10,DX_NAME
# 	0xA058D70F1269E0E70815C1D45566DC7F4EEEE94FDE83C5F0A6510829EABC4F90,0xAEB7963EE49387DE108EE9EEE4074E31180EB5BA8030F53955049DA6B5A02ADA,2016-11-30 08:28:00.000,2016-12-01 18:00:00.000,5,F10.10,"Alcohol abuse, uncomplicated"
# 	0x1CFA2B860E2ED78246BA5C52615127C777EFAA108196C9C8714CE7F665C9218E,0xE060C94DDA1265DD5F0F96D4431A7B148AB018D1A3DCAE36E7664826F22F7654,2016-11-30 08:28:00.000,2016-11-30 16:52:00.000,3,Z87.19,Personal history of other diseases of the digestive system
#
#
# File 24: ./HFHS Data/Compressed/WSU_HASHED_MRN_DX_HISTORY_Headers_and_CSV_and_Tab_delim/WSU_HASHED_MRN_DX_HISTORY_HEADERS.csv
#
# 	CSN_HASH,MRN_HASH,ARRIVAL,DISCHARGE,DX_LINE,ICD_10,DX_NAME
#
#
#
#
# File 25: ./HFHS Data/Compressed/WSU_HASHED_MRN_DX_HISTORY_Headers_and_CSV_and_Tab_delim/WSU_HASHED_MRN_DX_HISTORY_tab_delimited.txt
#
# 	﻿CSN_HASH	MRN_HASH	ARRIVAL	DISCHARGE	DX_LINE	ICD_10	DX_NAME
# 	0xA058D70F1269E0E70815C1D45566DC7F4EEEE94FDE83C5F0A6510829EABC4F90	0xAEB7963EE49387DE108EE9EEE4074E31180EB5BA8030F53955049DA6B5A02ADA	2016-11-30 08:28:00.000	2016-12-01 18:00:00.000	5	F10.10	Alcohol abuse, uncomplicated
# 	0x1CFA2B860E2ED78246BA5C52615127C777EFAA108196C9C8714CE7F665C9218E	0xE060C94DDA1265DD5F0F96D4431A7B148AB018D1A3DCAE36E7664826F22F7654	2016-11-30 08:28:00.000	2016-11-30 16:52:00.000	3	Z87.19	Personal history of other diseases of the digestive system
#
#
# File 26: ./HFHS Data/Compressed/WSU_HASHED_PROVIDER_IN_OUT/WSU_HASHED_PROVIDER_IN_OUT.csv
#
# 	﻿0xD7674D94562E99FBE7DDC038145C44A514F96EC84B09BAA7843FB23F832C2929,2015-08-14 04:48:49.000,2015-08-14 07:09:00.000,GUNAGA, SATHEESH,H10968,Physician
# 	0x6F0AA355B5F7D4C7BBB7823CD549686914CE15080AFCDE9F429D1975129E7923,2015-08-14 05:12:33.000,2015-08-14 07:47:11.000,SUSZANSKI, JULIAN,H108739,Physician
# 	0x6F0AA355B5F7D4C7BBB7823CD549686914CE15080AFCDE9F429D1975129E7923,2015-08-14 07:47:11.000,2015-08-14 10:43:00.000,DELEDDA, JOHN,H521441,Physician
#
#
# File 27: ./HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC/WSU_HASHED_VITALS_GLUCOSE_ETC.csv
#
# 	CSN_HASH,Vitals_time,Vital_name,Vital_value,disp_name,units,Vital_unit
# 	1852660FE44755815C9221E3E3FB5F59D04609CE465638B53D01BA8614645291,2014-06-01 13:42:00,WEIGHT/SCALE,2719.98,Weight,,Weight
# 	1852660FE44755815C9221E3E3FB5F59D04609CE465638B53D01BA8614645291,2014-06-01 15:15:00,TEMPERATURE,,Temp,,Temp
#
#
# File 28: ./HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1.csv
#
# 	﻿0x87019A1926A8B6E3166BA78036C6D2F313DFD4FD06732D9A67AD23784F910830,2014-07-07 07:59:00.000,R PAIN BODY LOCATION 1,Neck,Pain Location,NULL,Pain Location
# 	0xBBBF421B133676CCC738DCCB5A76117185FBFE59F7BAF6B53E6D57F49F0810F5,2014-07-07 08:02:00.000,TEMPERATURE,98.6,Temp,NULL,Temp
# 	0xBBBF421B133676CCC738DCCB5A76117185FBFE59F7BAF6B53E6D57F49F0810F5,2014-07-07 08:02:00.000,PULSE,64,Pulse,NULL,Pulse
#
#
# File 29: ./HFHS Data/Compressed/WSU_HASHED_VITALS_GLUCOSE_ETC_PT1-PT6/WSU_HASHED_VITALS_GLUCOSE_ETC_P
# 	0xA91D7DF1A8F09F8F2EBED119A7C86D1F2D3B5863D222BF0C8B0BAF71FDF64833,2016-10-06 17:00:00.000,PULSE OXIMETRY,96,SpO2,%,SpO2%
# 	0xA91D7DF1A8F09F8F2EBED119A7C86D1F2D3B5863D222BF0C8B0BAF71FDF64833,2016-10-06 17:00:00.000,RESPIRATIONS,18,Resp,NULL,Resp

# %% [markdown]
# ### II. `COMPLAINTS`
# Data located in the following paths and has the same two-column structure:
# * ` ./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS/WSU_HASHED_ALL_CHIEF_COMPLAINTS.csv`
# * ` ./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW.csv`
# * `./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspecified/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspecified.csv`

# %%
files =[
    "./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS/WSU_HASHED_ALL_CHIEF_COMPLAINTS.csv",
    "./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW/WSU_HASHED_ALL_CHIEF_COMPLAINTS_NEW.csv",
    "./HFHS Data/Compressed/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspecified/WSU_HASHED_ALL_CHIEF_COMPLAINTS_inc_unspecified.csv"
] 
linesall = []
for file in files: 
    with open(file, encoding="utf-8-sig", newline="") as f:
        lines = [line.rstrip("\r\n") for line in f]
        print(len(lines))
        linesall += lines
# Out:
# 1304325
# 1196461
# 1304324

# %%
linesall[:20]
# Out:
# ['CSN_HASH,ChiefComplaint',
#  '0x00000F5D77FB3D9F299A327BF784BE4878B53B45B2A4A3AAB20764E6F130B0EA,RASH',
#  '0x0000429B06ACE47BEAC568C8A6DD22F83037E7385DB9BBEFC998E6F9CBA79BFE,THREATENED MISCARRIAGE',
#  '0x000047E1F2AFD80852473CAB9C497A04806DFD30E4811916589D09012F708BB4,ANKLE INJURY',
#  '0x000071FF95F5359BD22F9FAFD5BFA6D9BABDEB41DA0AF44411A3D08FBFD04B3E,FALL',
#  '0x00007EECC66EB142F83F629880EBCE10D8E44D93529F535BC12AB91D6714C7ED,CHEST PAIN',
#  '0x00007EECC66EB142F83F629880EBCE10D8E44D93529F535BC12AB91D6714C7ED,MIGRAINE',
#  '0x000085F2DA284E359DF0674F7927765352D996D89828EF6586E9E9E7CF3FCB12,HAND INJURY',
#  '0x00009EA8CA6CF0DDE41C1299FDCAC6DED46CA1F03DEF6BE56987EC29E74B7581,EYE PAIN',
#  '0x0000C7DF25322909660E6620B6BBAFDFFFBFE6DF7E4FCF2EE1A0D9F929CADB5F,FEVER',
#  '0x0000D42CB54AE2FE77890CB269C06030763B07271340357F3C8E02384B684FC3,CHEST PAIN',
#  '0x0000D473A2572D9B834C929DFF3423F23B7D2D04233E4396CD7957B513C2A47B,*Unspecified',
#  '0x0000FEE380BC73FA21A2123366F9462AC1F33F7642002AF233FD2861162421E9,KNEE INJURY',
#  '0x0001020762B708EAFB308FA7DB2213F6A30B137F949357B9D62CBCB42065E417,TESTICLE PAIN',
#  '0x000103B7BA8257F9EF004FF0FACD09AAFF61E488D737D7897AADF8C8A08704FC,ABDOMINAL PAIN',
#  '0x00011A14B3DD7D71317B88E1F2CEDA1A7A76F6366013F14661C47FEB87AA0B76,ABDOMINAL PAIN',
#  '0x000120BC81D2690F8259A443B3C0AC6ABC8B2BD679F3966672DB217AF1A56005,FATIGUE',
#  '0x00012DB059AECAA02CC75D77B1CC3D0EF8C2D5DA6A13822A7846C1FBEFE38D7F,FAILURE TO THRIVE',
#  '0x00012DB059AECAA02CC75D77B1CC3D0EF8C2D5DA6A13822A7846C1FBEFE38D7F,ALTERED MENTAL STATUS',
#  '0x00013DBBDBAA0451FC2858800837B70BBD1618A64524D97874ACED076A0D1C68,*Unspecified']

# %%
'0x00013DBBDBAA0451FC2858800837B70BBD1618A64524D97874ACED076A0D1C68,*Unspecified'.endswith('*Unspecified')
# Out:
# True

# %%
'abc,d,f,'.find(',')
# Out:
# 3

# %%
linesall[0].split(',')
# Out:
# ['CSN_HASH', 'ChiefComplaint']

# %%
df = pl.DataFrame(
    {
        linesall[0].split(',')[0]: [i[:i.find(',')] for i in linesall[1:] if not i.endswith('*Unspecified')],
        linesall[0].split(',')[1]: [i[i.find(',')+1:] for i in linesall[1:] if not i.endswith('*Unspecified')]                         
    }
).unique()

df.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬────────────────┐
# │ CSN_HASH                        ┆ ChiefComplaint │
# │ ---                             ┆ ---            │
# │ str                             ┆ str            │
# ╞═════════════════════════════════╪════════════════╡
# │ 0x356B1E8928D45962EBF18123CA5C… ┆ ABDOMINAL PAIN │
# │ 0x38D383B01156CC386671F408063E… ┆ DRUG OVERDOSE  │
# │ 0xC7C223A1BC18453D3E9BD6D3E124… ┆ JOINT SWELLING │
# │ 0xF959304387C776261D9CFEF0A2DB… ┆ COUGH          │
# │ 0x8E491AEA88DFD30F7CD2A3352477… ┆ EYE PROBLEM    │
# └─────────────────────────────────┴────────────────┘

# %%
df["CSN_HASH"].n_unique()
# Out:
# 912385

# %%
df["CSN_HASH"].value_counts().sort("count", descending=True).head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ CSN_HASH                        ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ 0x6B2DC2E2ED33CB43016638D004EF… ┆ 9     │
# │ 0xF88C5780D001524D2A68DDA8EB9E… ┆ 9     │
# │ 0x4B593433664A23A5EC256FCB7CE0… ┆ 9     │
# │ 0x1E4D1DB30D6465717A1F448FED2D… ┆ 9     │
# │ 0x4434D886950528C3EBABEC7CAEDA… ┆ 8     │
# └─────────────────────────────────┴───────┘

# %% [markdown]
# ##### 1. Extract `CSN_HASH` and `CPT_CODE`

# %%
df = df.with_columns(
    pl.col("row")
    .str.split_exact(",", 1)
    .struct.rename_fields(["CSN_HASH", "other"])
    .alias("fields")
).unnest("fields").drop("other")

df = df.with_columns(
    pl.col("row")
    .str.reverse()
    .str.split_exact(",", 1)
    .struct.rename_fields(["CPT_CODE", "other"])
    .alias("fields")
).unnest("fields").drop("other")

df = df.with_columns(
    pl.col("CPT_CODE")
    .str.reverse()
)

assert df["CSN_HASH"].str.len_chars().mean() == 66
assert df["CSN_HASH"].null_count() == 0
assert df.filter(pl.col("CPT_CODE") == "NULL").shape[0] == 0
assert df["CPT_CODE"].null_count() == 0

df.head()
# Out:
# shape: (5, 3)
# ┌─────────────────────────────────┬─────────────────────────────────┬──────────┐
# │ row                             ┆ CSN_HASH                        ┆ CPT_CODE │
# │ ---                             ┆ ---                             ┆ ---      │
# │ str                             ┆ str                             ┆ str      │
# ╞═════════════════════════════════╪═════════════════════════════════╪══════════╡
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB747   │
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB747   │
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB276   │
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB462   │
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB462   │
# └─────────────────────────────────┴─────────────────────────────────┴──────────┘

# %% [markdown]
# ##### 2. Count `datetime` in each row
# Then subset the results.

# %%
#datetime_regex = r"^\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}$"
datetime_regex = r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}"

df = df.with_columns(
    pl.col("row").str.count_matches(datetime_regex).alias("dt_count")
)

df['dt_count'].value_counts().sort("count", descending=True)

# %%
df['dt_count'].value_counts().sort("count", descending=True)
# Out:
# shape: (4, 2)
# ┌──────────┬─────────┐
# │ dt_count ┆ count   │
# │ ---      ┆ ---     │
# │ u32      ┆ u32     │
# ╞══════════╪═════════╡
# │ 4        ┆ 8988198 │
# │ 2        ┆ 5098101 │
# │ 3        ┆ 589766  │
# │ 1        ┆ 3734    │
# └──────────┴─────────┘

# %%
#group_4 = df.filter(pl.col("dt_count") == 4).drop("dt_count")
#group_2 = df.filter(pl.col("dt_count") == 2).drop("dt_count")
#group_3 = df.filter(pl.col("dt_count") == 3).drop("dt_count")
group_1 = df.filter(pl.col("dt_count") == 1).drop("dt_count")
#assert group_4.shape[0] + group_2.shape[0] + group_3.shape[0] + group_1.shape[0] == df.shape[0]

# %% [markdown]
# ##### 3. Work date cols on `group_4`
# All records have four `datetime` substrings which is the maximum number expected.
# ```
# RESULT_TIME
# TEST_REQUEST_TIME
# TEST_START_TIME
# TEST_COMPLETE_TIME
# ```

# %%
group_4 = group_4.with_columns(
    pl.col("row")
    .str.slice(
        pl.col("row")
        .str.find(datetime_regex)
    )
    .str.splitn(",", 5)
    .struct.rename_fields(["RESULT_TIME", "RESULT_TYPE", "RESULT_FLAG", "ORD_VALUE", "OTHER"])
    .alias("t_break")
).unnest("t_break").drop(["RESULT_TIME", "RESULT_TYPE", "RESULT_FLAG", "OTHER"])

group_4.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬──────────┬─────────────┐
# │ row                             ┆ CSN_HASH                        ┆ CPT_CODE ┆ ORD_VALUE   │
# │ ---                             ┆ ---                             ┆ ---      ┆ ---         │
# │ str                             ┆ str                             ┆ str      ┆ str         │
# ╞═════════════════════════════════╪═════════════════════════════════╪══════════╪═════════════╡
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB747   ┆ 0.11        │
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB747   ┆ 7.73        │
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB276   ┆ AB POSITIVE │
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB462   ┆ Blood       │
# │ 0x6866B1E321722786E0C3CFBAF02E… ┆ 0x6866B1E321722786E0C3CFBAF02E… ┆ LAB462   ┆ Blood       │
# └─────────────────────────────────┴─────────────────────────────────┴──────────┴─────────────┘

# %% [markdown]
# **Note**: We should consider returning statistics on the position of the first datetime in order to estimate whether or not a `RESULT_TIME` is present.
#
# Assumption: Just because there are three other times, doesn't mean that the test yielded a valid result; this can be evaluated by attempting to extract values at the `ORD_VALUE` and testing for nulls.

# %%
group_4.with_columns(
    pl.col("row")
    .str.find(datetime_regex)
    .alias("first_dt_pos")
)["first_dt_pos"].describe()
# Out:
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ value      │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 8.988198e6 │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 127.70241  │
# │ std        ┆ 28.825124  │
# │ min        ┆ 103.0      │
# │ 25%        ┆ 114.0      │
# │ 50%        ┆ 123.0      │
# │ 75%        ┆ 129.0      │
# │ max        ┆ 385.0      │
# └────────────┴────────────┘

# %%
group_4.shape[0] / df.shape[0]
# Out:
# 0.6122834515649703

# %%
fields = ["RESULT_TIME", "TEST_REQUEST_TIME", "TEST_START_TIME", "TEST_COMPLETE_TIME"]

group_4 = group_4.with_columns(
    pl.col("row")
    .str.extract_all(datetime_regex)
    .list.to_struct(fields=fields)
    .alias("dts")
).unnest("dts")

group_4 = group_4.with_columns(
    pl.col("^.*_TIME$")
    .str.to_datetime()
)

group_4.head()
# Out:
# shape: (5, 8)
# ┌────────────┬────────────┬──────────┬────────────┬────────────┬───────────┬───────────┬───────────┐
# │ row        ┆ CSN_HASH   ┆ CPT_CODE ┆ ORD_VALUE  ┆ RESULT_TIM ┆ TEST_REQU ┆ TEST_STAR ┆ TEST_COMP │
# │ ---        ┆ ---        ┆ ---      ┆ ---        ┆ E          ┆ EST_TIME  ┆ T_TIME    ┆ LETE_TIME │
# │ str        ┆ str        ┆ str      ┆ str        ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆          ┆            ┆ datetime[μ ┆ datetime[ ┆ datetime[ ┆ datetime[ │
# │            ┆            ┆          ┆            ┆ s]         ┆ μs]       ┆ μs]       ┆ μs]       │
# ╞════════════╪════════════╪══════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 0x6866B1E3 ┆ 0x6866B1E3 ┆ LAB747   ┆ 0.11       ┆ 2014-08-15 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-1 │
# │ 21722786E0 ┆ 21722786E0 ┆          ┆            ┆ 18:49:00   ┆ 5         ┆ 5         ┆ 5         │
# │ C3CFBAF02E ┆ C3CFBAF02E ┆          ┆            ┆            ┆ 17:10:00  ┆ 17:09:00  ┆ 18:49:00  │
# │ …          ┆ …          ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 0x6866B1E3 ┆ 0x6866B1E3 ┆ LAB747   ┆ 7.73       ┆ 2014-08-15 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-1 │
# │ 21722786E0 ┆ 21722786E0 ┆          ┆            ┆ 21:59:00   ┆ 5         ┆ 5         ┆ 5         │
# │ C3CFBAF02E ┆ C3CFBAF02E ┆          ┆            ┆            ┆ 17:10:00  ┆ 20:09:00  ┆ 21:59:00  │
# │ …          ┆ …          ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 0x6866B1E3 ┆ 0x6866B1E3 ┆ LAB276   ┆ AB         ┆ 2014-08-15 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-1 │
# │ 21722786E0 ┆ 21722786E0 ┆          ┆ POSITIVE   ┆ 18:11:00   ┆ 5         ┆ 5         ┆ 5         │
# │ C3CFBAF02E ┆ C3CFBAF02E ┆          ┆            ┆            ┆ 17:10:00  ┆ 17:10:00  ┆ 18:11:00  │
# │ …          ┆ …          ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 0x6866B1E3 ┆ 0x6866B1E3 ┆ LAB462   ┆ Blood      ┆ 2014-08-20 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-2 │
# │ 21722786E0 ┆ 21722786E0 ┆          ┆            ┆ 15:53:00   ┆ 5         ┆ 5         ┆ 0         │
# │ C3CFBAF02E ┆ C3CFBAF02E ┆          ┆            ┆            ┆ 17:12:00  ┆ 17:12:00  ┆ 15:53:00  │
# │ …          ┆ …          ┆          ┆            ┆            ┆           ┆           ┆           │
# │ 0x6866B1E3 ┆ 0x6866B1E3 ┆ LAB462   ┆ Blood      ┆ 2014-08-20 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-2 │
# │ 21722786E0 ┆ 21722786E0 ┆          ┆            ┆ 10:36:00   ┆ 5         ┆ 5         ┆ 0         │
# │ C3CFBAF02E ┆ C3CFBAF02E ┆          ┆            ┆            ┆ 17:12:00  ┆ 17:27:00  ┆ 10:36:00  │
# │ …          ┆ …          ┆          ┆            ┆            ┆           ┆           ┆           │
# └────────────┴────────────┴──────────┴────────────┴────────────┴───────────┴───────────┴───────────┘

# %%
group_4[fields].describe()
# Out:
# shape: (9, 5)
# ┌────────────┬─────────────────┬──────────────────────┬──────────────────────┬─────────────────────┐
# │ statistic  ┆ RESULT_TIME     ┆ TEST_REQUEST_TIME    ┆ TEST_START_TIME      ┆ TEST_COMPLETE_TIME  │
# │ ---        ┆ ---             ┆ ---                  ┆ ---                  ┆ ---                 │
# │ str        ┆ str             ┆ str                  ┆ str                  ┆ str                 │
# ╞════════════╪═════════════════╪══════════════════════╪══════════════════════╪═════════════════════╡
# │ count      ┆ 8988198         ┆ 8988198              ┆ 8988198              ┆ 8988198             │
# │ null_count ┆ 0               ┆ 0                    ┆ 0                    ┆ 0                   │
# │ mean       ┆ 2015-08-29      ┆ 2015-08-28           ┆ 2015-08-28           ┆ 2015-08-29          │
# │            ┆ 00:26:49.559569 ┆ 16:22:33.906623      ┆ 17:16:22.341771      ┆ 00:26:49.559569     │
# │ std        ┆ null            ┆ null                 ┆ null                 ┆ null                │
# │ min        ┆ 2013-12-03      ┆ 2012-05-04 17:45:00  ┆ 2012-05-04 17:45:00  ┆ 2013-12-03 00:00:00 │
# │            ┆ 00:00:00        ┆                      ┆                      ┆                     │
# │ 25%        ┆ 2015-01-05      ┆ 2015-01-05 12:08:00  ┆ 2015-01-05 12:17:00  ┆ 2015-01-05 13:28:00 │
# │            ┆ 13:28:00        ┆                      ┆                      ┆                     │
# │ 50%        ┆ 2015-08-28      ┆ 2015-08-28 13:51:00  ┆ 2015-08-28 13:59:00  ┆ 2015-08-28 21:15:00 │
# │            ┆ 21:15:00        ┆                      ┆                      ┆                     │
# │ 75%        ┆ 2016-04-19      ┆ 2016-04-19 06:48:00  ┆ 2016-04-19 07:03:00  ┆ 2016-04-19 14:47:00 │
# │            ┆ 14:47:00        ┆                      ┆                      ┆                     │
# │ max        ┆ 2016-12-21      ┆ 2016-12-20 23:57:00  ┆ 2016-12-21 00:01:00  ┆ 2016-12-21 00:03:00 │
# │            ┆ 00:03:00        ┆                      ┆                      ┆                     │
# └────────────┴─────────────────┴──────────────────────┴──────────────────────┴─────────────────────┘

# %%
group_4.with_columns(
    pl.when(
        pl.col.TEST_REQUEST_TIME <= pl.col.TEST_START_TIME, 
        pl.col.TEST_START_TIME <= pl.col.TEST_COMPLETE_TIME, 
        pl.col.TEST_COMPLETE_TIME <= pl.col.RESULT_TIME, 
    )
    .then(1)
    .otherwise(0)
    .alias("t_val_test")
)["t_val_test"].mean()
# Out:
# 0.861753601778688

# %% [markdown]
# 86% of records abide by this logic; therefore, we shall assign the min value (in this case, typically `TEST_REQUEST_TIME`) to the "test ordered" event and the max value (in this case, typically the `RESULT_TIME`) to the `ORD_VALUE` event.

# %%
group_4 = group_4.select(
    pl.col("CSN_HASH"), 
    pl.min_horizontal(fields).alias("datetime_val"),
    pl.col("CPT_CODE").alias("cat"),
    pl.lit("test ordered").alias("val")
).vstack(
    group_4.select(
        pl.col("CSN_HASH"), 
        pl.max_horizontal(fields).alias("datetime_val"),
        pl.col("CPT_CODE").alias("cat"),
        pl.col("ORD_VALUE").alias("val")
    )
).unique()

# %%
group_4.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat    ┆ val          │
# │ ---                             ┆ ---                 ┆ ---    ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str    ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪════════╪══════════════╡
# │ 0x3502D3DDCFED393A57065B5DB87B… ┆ 2014-07-05 21:09:00 ┆ LAB293 ┆ test ordered │
# │ 0xCA6333496B2A04C3958BBDA1C663… ┆ 2014-06-29 10:11:00 ┆ LAB15  ┆ test ordered │
# │ 0xFC9BEED592C923C32ED7308CE278… ┆ 2015-05-21 18:37:00 ┆ LAB747 ┆ test ordered │
# │ 0x9AC236D9873985DA48BD173BAA1F… ┆ 2015-11-25 00:00:00 ┆ LAB15  ┆ test ordered │
# │ 0xFC209EF7EC8D39623CB879BB616F… ┆ 2016-09-10 01:09:00 ┆ LAB15  ┆ test ordered │
# └─────────────────────────────────┴─────────────────────┴────────┴──────────────┘

# %%
group_4.tail()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat    ┆ val          │
# │ ---                             ┆ ---                 ┆ ---    ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str    ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪════════╪══════════════╡
# │ 0x5A8276FB63D77813AE4FB025C547… ┆ 2014-07-06 14:44:00 ┆ LAB144 ┆ test ordered │
# │ 0x2C3E077F355F3A99F58BD94A3D3D… ┆ 2015-04-10 16:00:00 ┆ LAB15  ┆ test ordered │
# │ 0x2C3CA8E8E3CA151990B3CD43BD99… ┆ 2016-04-23 15:12:00 ┆ LAB56  ┆ test ordered │
# │ 0x1242DDF9A9DC1C1978B6E99F7EF8… ┆ 2016-09-20 16:28:00 ┆ LAB347 ┆ test ordered │
# │ 0x4CF38D8B907C96C44AFB3234483F… ┆ 2015-06-04 07:30:00 ┆ LAB47  ┆ 61           │
# └─────────────────────────────────┴─────────────────────┴────────┴──────────────┘

# %% [markdown]
# ##### 4. Work date cols on `group_2`
# Are the date columns next to each other? This implies the pattern `r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}\,\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}"`
# * If columns are next to each other then `RESULT_TIME` is **not** one of the columns.
# * But does this imply that there is null/missing value in `ORD_VALUE`? Assumption is "yes"...

# %%
datetime_regex = r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}\,\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}"

group_2 = group_2.with_columns(
    pl.col("row").str.count_matches(datetime_regex).alias("dt_count")
)

group_2['dt_count'].value_counts().sort("count", descending=True)
# Out:
# shape: (1, 2)
# ┌──────────┬─────────┐
# │ dt_count ┆ count   │
# │ ---      ┆ ---     │
# │ u32      ┆ u32     │
# ╞══════════╪═════════╡
# │ 1        ┆ 5098101 │
# └──────────┴─────────┘

# %% [markdown]
# This result implies that there is null-missing value in `ORD_VALUE` position. There should be some verification that this assumption is true.

# %%
group_2["row"].slice(0, 1).to_numpy()
# Out:
# array(['0x51037B01B901FAF48B5A11D751286588069F239006576FE6763069FE1BD08C81,161179022,Check Blood Pressure,41461,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,2015-08-20 02:25:00.000,2015-08-20 02:26:00.000,NULL,H18067,NEHER, GARY,NUR432'],
#       dtype=object)

# %%
group_2["row"].slice(-1, 1).to_numpy()
# Out:
# array(['0xD94CA78574F49681C751D4C2A3043EA3DAF1AC4C2C798CEACEB90D1B10E3EF45,160023404,Insert saline lock,103471,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,2016-03-25 19:21:00.000,2016-03-25 19:21:00.000,NULL,H16158,AL-SAADI, HAIDAR,NUR872'],
#       dtype=object)

# %% [markdown]
# We could consider counting number of `NULL` in each string in `group_2` before making a final decision that *all `group_2` consist only of 'test ordered' events and no 'test result' events*
#
# Subsequent steps would then include extracting the datetime values, finding their minimum, and thenn formatting the results as was done for `group_4` subset.

# %%
group_2 = group_2.with_columns(
    pl.col("row").str.count_matches("NULL", literal=True).alias("NULL_count")
)

group_2['NULL_count'].value_counts().sort("count", descending=True)
# Out:
# shape: (3, 2)
# ┌────────────┬─────────┐
# │ NULL_count ┆ count   │
# │ ---        ┆ ---     │
# │ u32        ┆ u32     │
# ╞════════════╪═════════╡
# │ 13         ┆ 3915946 │
# │ 11         ┆ 1170663 │
# │ 14         ┆ 11492   │
# └────────────┴─────────┘

# %%
group_2.filter(pl.col("NULL_count") == 14)["row"].slice(0, 1).to_numpy()
# Out:
# array(['0xEF8DD3DDF35699C4EC3E2A6788C10CF79CE98A5A5D9380F4E3588460298561D8,121558609,NULL,885,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,2015-01-06 00:03:00.000,2015-01-06 00:04:00.000,NULL,H89165,CLUFF, STEPHEN,NUR185'],
#       dtype=object)

# %%
group_2.filter(pl.col("NULL_count") == 11)["row"].slice(0, 1).to_numpy()
# Out:
# array(['0x4570DC4CA5E77C170A0726FFBB9BFB4E57AF5646C968B7609B87CF932B3FA0B1,198752036,ECG 12 Lead now and in 3 hours,509,MUSE,14,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,2016-06-09 16:56:00.000,2016-06-09 18:00:00.000,NULL,H7781,DRAKE, CASSIUS M,ECG1'],
#       dtype=object)

# %%
group_2.filter(pl.col("NULL_count") == 13)["row"].slice(0, 1).to_numpy()
# Out:
# array(['0x51037B01B901FAF48B5A11D751286588069F239006576FE6763069FE1BD08C81,161179022,Check Blood Pressure,41461,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,2015-08-20 02:25:00.000,2015-08-20 02:26:00.000,NULL,H18067,NEHER, GARY,NUR432'],
#       dtype=object)

# %% [markdown]
# Let's verify that a series of ten consecutive `NULL` exist in each string:

# %%
group_2 = group_2.with_columns(
    pl.col("row").str.count_matches(10 * ',NULL' + ',', literal=True).alias("10_NULL_count")
)

group_2['10_NULL_count'].value_counts().sort("count", descending=True)
# Out:
# shape: (1, 2)
# ┌───────────────┬─────────┐
# │ 10_NULL_count ┆ count   │
# │ ---           ┆ ---     │
# │ u32           ┆ u32     │
# ╞═══════════════╪═════════╡
# │ 1             ┆ 5098101 │
# └───────────────┴─────────┘

# %% [markdown]
# Since there are a series of ten consecutive `NULL` values we consider there to be no results in subset `group_2` and therefore process it *only* as "test requested" events.

# %%
fields = ["TEST_REQUEST_TIME", "TEST_START_TIME"]

group_2 = group_2.with_columns(
    pl.col("row")
    .str.extract_all(datetime_regex)
    .list.get(0)
    .str.split(by=",")
    .alias("dts")        
    .list.to_struct(fields=fields)
).unnest("dts")

group_2 = group_2.with_columns(
    pl.col("^.*_TIME$")
    .str.to_datetime()
)

group_2 = group_2.select(
    pl.col("CSN_HASH"), 
    pl.min_horizontal(fields).alias("datetime_val"),
    pl.col("CPT_CODE").alias("cat"),
    pl.lit("test ordered").alias("val")
).unique()

group_2.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬──────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat      ┆ val          │
# │ ---                             ┆ ---                 ┆ ---      ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str      ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪══════════╪══════════════╡
# │ 0x86DA87B0958100F93A3006F37FBD… ┆ 2016-04-18 17:26:00 ┆ NUR478   ┆ test ordered │
# │ 0xF170C1EB0DADE73ADFA3EC8BFA9F… ┆ 2016-10-31 11:17:00 ┆ VAS30414 ┆ test ordered │
# │ 0xDE49729D1F01DCC9532F87B14301… ┆ 2015-06-07 20:54:00 ┆ PRO179B  ┆ test ordered │
# │ 0x69BF04A04D5C1A0C3FA581475C0A… ┆ 2016-02-01 02:43:00 ┆ COR25    ┆ test ordered │
# │ 0x79564F04EE725A209C4FC16C2367… ┆ 2014-07-18 00:20:00 ┆ EQ97     ┆ test ordered │
# └─────────────────────────────────┴─────────────────────┴──────────┴──────────────┘

# %% [markdown]
# ##### 5. Work date cols on `group_3`
# Are the date columns next to each other? This implies the pattern `r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}\,\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}\,\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}"`
# * If columns are next to each other then `RESULT_TIME` is **not** one of the columns.
# * But does this imply that there is null/missing value in `ORD_VALUE`? Assumption is "yes"...

# %%
datetime_regex = r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}\,\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}\,\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}"

group_3 = group_3.with_columns(
    pl.col("row").str.count_matches(datetime_regex).alias("dt_count")
)

group_3['dt_count'].value_counts().sort("count", descending=True)
# Out:
# shape: (2, 2)
# ┌──────────┬────────┐
# │ dt_count ┆ count  │
# │ ---      ┆ ---    │
# │ u32      ┆ u32    │
# ╞══════════╪════════╡
# │ 1        ┆ 589729 │
# │ 0        ┆ 37     │
# └──────────┴────────┘

# %% [markdown]
# For results where `dt_count == 1` we can assume all of these records should be "test ordered" or verify using series of 10 NULL method.
#
# For results where `dt_count == 0` this implies that since there are only three total datetimes in the record and they are not one after another, this means that one of the datetimes is in the `RESULT_TIME` position. We should assume that these records have valid `ORD_VALUE` which needs to be extracted.

# %%
group_3_1 = group_3.filter(pl.col("dt_count") == 1)

group_3_1 = group_3_1.with_columns(
    pl.col("row").str.count_matches(10 * ',NULL' + ',', literal=True).alias("10_NULL_count")
)

group_3_1['10_NULL_count'].value_counts().sort("count", descending=True)
# Out:
# shape: (1, 2)
# ┌───────────────┬────────┐
# │ 10_NULL_count ┆ count  │
# │ ---           ┆ ---    │
# │ u32           ┆ u32    │
# ╞═══════════════╪════════╡
# │ 1             ┆ 589729 │
# └───────────────┴────────┘

# %% [markdown]
# Since there are a series of ten consecutive `NULL` values we consider there to be no results in subset `group_3_1` and therefore process it *only* as "test requested" events.

# %%
datetime_regex = r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}"

fields = ["TEST_REQUEST_TIME", "TEST_START_TIME", "TEST_COMPLETE_TIME"]

group_3_1 = group_3_1.with_columns(
    pl.col("row")
    .str.extract_all(datetime_regex)
    .list.to_struct(fields=fields)
    .alias("dts")            
).unnest("dts")

group_3_1 = group_3_1.with_columns(
    pl.col("^.*_TIME$")
    .str.to_datetime()
)

group_3_1 = group_3_1.select(
    pl.col("CSN_HASH"), 
    pl.min_horizontal(fields).alias("datetime_val"),
    pl.col("CPT_CODE").alias("cat"),
    pl.lit("test ordered").alias("val")
).unique()

group_3_1.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬──────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat      ┆ val          │
# │ ---                             ┆ ---                 ┆ ---      ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str      ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪══════════╪══════════════╡
# │ 0xB632D4A2599EAC631263CCEA0E6F… ┆ 2016-10-04 07:29:00 ┆ IMG2669  ┆ test ordered │
# │ 0x7194DEA59D312A1CC699E1195983… ┆ 2015-12-12 07:44:00 ┆ CH 1V    ┆ test ordered │
# │ 0xC1D878516F4EA5823A35900A12F9… ┆ 2016-12-01 17:41:00 ┆ CTHDWO   ┆ test ordered │
# │ 0x74C565DD97AF8C76F890A19184DE… ┆ 2016-02-21 06:09:00 ┆ CTHDWO   ┆ test ordered │
# │ 0x3FAD13B090A102284142436E682A… ┆ 2016-03-09 09:21:00 ┆ MRCPBPWO ┆ test ordered │
# └─────────────────────────────────┴─────────────────────┴──────────┴──────────────┘

# %%
group_3_0 = group_3.filter(pl.col("dt_count") == 0)

group_3_0 = group_3_0.with_columns(
    pl.col("row")
    .str.slice(
        pl.col("row")
        .str.find(datetime_regex)
    )
    .str.splitn(",", 5)
    .struct.rename_fields(["RESULT_TIME", "RESULT_TYPE", "RESULT_FLAG", "ORD_VALUE", "OTHER"])
    .alias("t_break")
).unnest("t_break").drop(["RESULT_TIME", "RESULT_TYPE", "RESULT_FLAG", "OTHER"])

group_3_0.head()
# Out:
# shape: (5, 5)
# ┌────────────────────────────────┬───────────────────────────────┬──────────┬──────────┬───────────┐
# │ row                            ┆ CSN_HASH                      ┆ CPT_CODE ┆ dt_count ┆ ORD_VALUE │
# │ ---                            ┆ ---                           ┆ ---      ┆ ---      ┆ ---       │
# │ str                            ┆ str                           ┆ str      ┆ u32      ┆ str       │
# ╞════════════════════════════════╪═══════════════════════════════╪══════════╪══════════╪═══════════╡
# │ 0x338B093CC4FD95901B062BB9B11F ┆ 0x338B093CC4FD95901B062BB9B11 ┆ LAB53611 ┆ 0        ┆ 14        │
# │ …                              ┆ F…                            ┆          ┆          ┆           │
# │ 0x4838EC67B2935BA9E0B63D21F05C ┆ 0x4838EC67B2935BA9E0B63D21F05 ┆ LAB13446 ┆ 0        ┆ 48        │
# │ …                              ┆ C…                            ┆          ┆          ┆           │
# │ 0xD09279E24C00459C7A5F8B970814 ┆ 0xD09279E24C00459C7A5F8B97081 ┆ LAB13446 ┆ 0        ┆ 44        │
# │ …                              ┆ 4…                            ┆          ┆          ┆           │
# │ 0x49D78EA9C975AA47DEAC8ACC0A2C ┆ 0x49D78EA9C975AA47DEAC8ACC0A2 ┆ LAB13446 ┆ 0        ┆ 22        │
# │ …                              ┆ C…                            ┆          ┆          ┆           │
# │ 0x0AD9FC9D41B7AB631C37A1336520 ┆ 0x0AD9FC9D41B7AB631C37A133652 ┆ LAB2100  ┆ 0        ┆ 0.29      │
# │ …                              ┆ 0…                            ┆          ┆          ┆           │
# └────────────────────────────────┴───────────────────────────────┴──────────┴──────────┴───────────┘

# %%
fields = ["TEST_RESULT_TIME", "TEST_REQUEST_TIME", "TEST_START_TIME"]

group_3_0 = group_3_0.with_columns(
    pl.col("row")
    .str.extract_all(datetime_regex)
    .list.to_struct(fields=fields)
    .alias("dts")            
).unnest("dts")

group_3_0 = group_3_0.with_columns(
    pl.col("^.*_TIME$")
    .str.to_datetime()
)

group_3_0 = group_3_0.select(
    pl.col("CSN_HASH"), 
    pl.min_horizontal(fields).alias("datetime_val"),
    pl.col("CPT_CODE").alias("cat"),
    pl.lit("test ordered").alias("val")
).vstack(
    group_3_0.select(
        pl.col("CSN_HASH"), 
        pl.max_horizontal(fields).alias("datetime_val"),
        pl.col("CPT_CODE").alias("cat"),
        pl.col("ORD_VALUE").alias("val")
    )
).unique()

group_3_0.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬───────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat       ┆ val          │
# │ ---                             ┆ ---                 ┆ ---       ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str       ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪═══════════╪══════════════╡
# │ 0xEB022C5D921F92C2A3A180F7B3A1… ┆ 2015-04-09 11:04:00 ┆ LAB955    ┆ test ordered │
# │ 0x4A50C26B97BE59E0A7F2DF81F96E… ┆ 2016-05-04 13:03:00 ┆ LAB101760 ┆ 1            │
# │ 0xDCA81555E53DEF32C674E5C72C82… ┆ 2015-09-17 00:52:00 ┆ LAB10120  ┆ test ordered │
# │ 0xF19243C05040EB11F21BBBD4BA26… ┆ 2016-04-17 19:55:00 ┆ LAB101760 ┆ test ordered │
# │ 0x4A50C26B97BE59E0A7F2DF81F96E… ┆ 2016-05-03 10:16:00 ┆ LAB101761 ┆ test ordered │
# └─────────────────────────────────┴─────────────────────┴───────────┴──────────────┘

# %%
group_3_0.tail()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬───────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat       ┆ val          │
# │ ---                             ┆ ---                 ┆ ---       ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str       ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪═══════════╪══════════════╡
# │ 0x8D5B762BC51C7B98C6DAFEB0423F… ┆ 2016-05-02 10:38:00 ┆ LAB101760 ┆ 1            │
# │ 0x29216A98CB98380363EFB3E2CE43… ┆ 2016-04-07 03:13:00 ┆ LAB101760 ┆ test ordered │
# │ 0xBDF229A080940F0744CDF3FBEFCD… ┆ 2015-04-17 09:53:00 ┆ LAB955    ┆ Stool        │
# │ 0x8D5B762BC51C7B98C6DAFEB0423F… ┆ 2016-05-01 19:24:00 ┆ LAB101760 ┆ test ordered │
# │ 0x374D9692BFD0E0FAF75EE80EBF9F… ┆ 2016-03-08 19:21:00 ┆ LAB12076  ┆ test ordered │
# └─────────────────────────────────┴─────────────────────┴───────────┴──────────────┘

# %% [markdown]
# #### 6. Group 1

# %%
group_1 = group_1.with_columns(
    pl.col("row").str.count_matches(12 * ',NULL' + ',', literal=True).alias("12_NULL_count")
)

group_1['12_NULL_count'].value_counts().sort("count", descending=True)
# Out:
# shape: (1, 2)
# ┌───────────────┬───────┐
# │ 12_NULL_count ┆ count │
# │ ---           ┆ ---   │
# │ u32           ┆ u32   │
# ╞═══════════════╪═══════╡
# │ 1             ┆ 3734  │
# └───────────────┴───────┘

# %% [markdown]
# Since there are 12 consecutie `NULL` in a series then transform this subset all as "test ordered" only.

# %%
group_1 = group_1.with_columns(
    pl.col("row")
    .str.extract(datetime_regex, 0)
    .alias("_TIME")            
)

group_1 = group_1.with_columns(
    pl.col("^.*_TIME$")
    .str.to_datetime()
)

group_1 = group_1.select(
    pl.col("CSN_HASH"), 
    pl.col("_TIME").alias("datetime_val"),
    pl.col("CPT_CODE").alias("cat"),
    pl.lit("test ordered").alias("val")
).unique()

group_1.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬──────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat      ┆ val          │
# │ ---                             ┆ ---                 ┆ ---      ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str      ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪══════════╪══════════════╡
# │ 0x154A689F405B6BF88CEE2B37A8F1… ┆ 2015-10-22 13:47:00 ┆ GI2102   ┆ test ordered │
# │ 0x3DA0474F522C2D7B97D4F1D53BB7… ┆ 2015-05-12 14:42:00 ┆ GI2100   ┆ test ordered │
# │ 0x3292AF0875932908836E99E24148… ┆ 2016-02-25 11:47:00 ┆ GI2      ┆ test ordered │
# │ 0x795BE7CBBE8006D633A17DCF387D… ┆ 2016-12-07 17:09:00 ┆ PRO21013 ┆ test ordered │
# │ 0xD5EF8AA2E8F33C0E3CB7A8B2A4B4… ┆ 2016-01-19 17:17:00 ┆ GI210100 ┆ test ordered │
# └─────────────────────────────────┴─────────────────────┴──────────┴──────────────┘

# %% [markdown]
# #### 7. Reconstitute

# %%
df_out = pl.concat(
    [
        group_1, 
        group_2, 
        group_3_0, 
        group_3_1, 
        group_4
    ]
).unique()

df_out.shape
# Out:
# (23210213, 4)

# %%
23213049 - 23210213
# Out:
# 2836

# %%
df_out.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬──────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat      ┆ val          │
# │ ---                             ┆ ---                 ┆ ---      ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str      ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪══════════╪══════════════╡
# │ 0x154A689F405B6BF88CEE2B37A8F1… ┆ 2015-10-22 13:47:00 ┆ GI2102   ┆ test ordered │
# │ 0x3DA0474F522C2D7B97D4F1D53BB7… ┆ 2015-05-12 14:42:00 ┆ GI2100   ┆ test ordered │
# │ 0x3292AF0875932908836E99E24148… ┆ 2016-02-25 11:47:00 ┆ GI2      ┆ test ordered │
# │ 0x795BE7CBBE8006D633A17DCF387D… ┆ 2016-12-07 17:09:00 ┆ PRO21013 ┆ test ordered │
# │ 0xD5EF8AA2E8F33C0E3CB7A8B2A4B4… ┆ 2016-01-19 17:17:00 ┆ GI210100 ┆ test ordered │
# └─────────────────────────────────┴─────────────────────┴──────────┴──────────────┘

# %%
df_out.tail()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────┬────────┬──────────────┐
# │ CSN_HASH                        ┆ datetime_val        ┆ cat    ┆ val          │
# │ ---                             ┆ ---                 ┆ ---    ┆ ---          │
# │ str                             ┆ datetime[μs]        ┆ str    ┆ str          │
# ╞═════════════════════════════════╪═════════════════════╪════════╪══════════════╡
# │ 0x5A8276FB63D77813AE4FB025C547… ┆ 2014-07-06 14:44:00 ┆ LAB144 ┆ test ordered │
# │ 0x2C3E077F355F3A99F58BD94A3D3D… ┆ 2015-04-10 16:00:00 ┆ LAB15  ┆ test ordered │
# │ 0x2C3CA8E8E3CA151990B3CD43BD99… ┆ 2016-04-23 15:12:00 ┆ LAB56  ┆ test ordered │
# │ 0x1242DDF9A9DC1C1978B6E99F7EF8… ┆ 2016-09-20 16:28:00 ┆ LAB347 ┆ test ordered │
# │ 0x4CF38D8B907C96C44AFB3234483F… ┆ 2015-06-04 07:30:00 ┆ LAB47  ┆ 61           │
# └─────────────────────────────────┴─────────────────────┴────────┴──────────────┘

# %% [markdown]
# #### EXTRA: Working with comma position information

# %%
# Step 2: Add a new column to count the number of commas in each row
df = df.with_columns(
    pl.col("row").str.count_matches(",", literal=True).alias("comma_count")
)

# %%
# Step 3: Partition the rows based on the number of commas
#  - Rows with 22 commas
group_22_commas = df.filter(pl.col("comma_count") == 22)

#  - Rows with more than 22
group_gt22_commas = df.filter(pl.col("comma_count") > 22)

#  - Rows with more than 22
group_lt22_commas = df.filter(pl.col("comma_count") < 22)

# %%
print(group_22_commas.shape[0], group_gt22_commas.shape[0], group_lt22_commas.shape[0])
# Out:
# 10622056 4057743 0

# %%
group_22_commas.shape[0] + group_gt22_commas.shape[0] + group_lt22_commas.shape[0] == 14679799
# Out:
# True

# %%
group_gt22_commas = group_gt22_commas.with_columns(
    pl.col("row").str.count_matches("\s*,\s+|\s+,\s*", literal=False).alias("special_cond_count")
)

# %%
group_gt22_commas.slice(0, 1).to_numpy()[0, 0]
# Out:
# '0x6866B1E321722786E0C3CFBAF02E276B733967073B9099CC5C0D81857D37694D,96885439,Troponin I now, then in 3 hours,64647,SUNQUEST,12,41,NULL,2014-08-15 18:49:00.000,Final result,High,0.11,NULL,NULL,ng/mL,NULL,2014-08-15 17:10:00.000,2014-08-15 17:09:00.000,2014-08-15 18:49:00.000,H123700,VOELTZ, MICHELE,LAB747'

# %%
group_22_commas.slice(0, 1).to_numpy()[0, 0]
# Out:
# '0x6866B1E321722786E0C3CFBAF02E276B733967073B9099CC5C0D81857D37694D,96885441,Type and screen,1364,SUNQUEST,12,41,NULL,2014-08-15 18:11:00.000,Final result,NULL,AB POSITIVE,NULL,NULL,NULL,NULL,2014-08-15 17:10:00.000,2014-08-15 17:10:00.000,2014-08-15 18:11:00.000,H17974,BALIGA, SUDHIR,LAB276'

# %%
print(
    group_gt22_commas['special_cond_count']
    .value_counts()
    .sort("count", descending=True)
    .head()
)
# Out:
# shape: (5, 2)
# ┌────────────────────┬─────────┐
# │ special_cond_count ┆ count   │
# │ ---                ┆ ---     │
# │ u32                ┆ u32     │
# ╞════════════════════╪═════════╡
# │ 2                  ┆ 3625607 │
# │ 3                  ┆ 350027  │
# │ 4                  ┆ 63051   │
# │ 1                  ┆ 18615   │
# │ 5                  ┆ 293     │
# └────────────────────┴─────────┘

# %%
group_gt22_commas.filter(pl.col('special_cond_count') == 1).slice(0, 1).to_numpy()[0, 0]
# Out:
# '0x58C33A0015F6CD6C32E9D8289BF8A8A1A2D4055F7C0BD109E595F1F49CB5314D,96887469,LDH,Total,840,SUNQUEST,12,41,NULL,2014-08-16 06:28:00.000,Final result,NULL,215,100,220,IU/L,Y,2014-08-16 01:00:00.000,2014-08-16 05:00:00.000,2014-08-16 06:28:00.000,H131370,BHANSALI, HARDIK,LAB96'

# %%
group_gt22_commas.filter(pl.col('special_cond_count') == 2).slice(0, 1).to_numpy()[0, 0]
# Out:
# '0x6866B1E321722786E0C3CFBAF02E276B733967073B9099CC5C0D81857D37694D,96885439,Troponin I now, then in 3 hours,64647,SUNQUEST,12,41,NULL,2014-08-15 18:49:00.000,Final result,High,0.11,NULL,NULL,ng/mL,NULL,2014-08-15 17:10:00.000,2014-08-15 17:09:00.000,2014-08-15 18:49:00.000,H123700,VOELTZ, MICHELE,LAB747'

# %%
group_gt22_commas.filter(pl.col('special_cond_count') == 3).slice(0, 1).to_numpy()[0, 0]
# Out:
# '0x24E04C33FFBFA485598CD345F162263DD571BB9842540A12BEBD000684AD2156,96886483,POC Glucose, metered, outpatient,123893,SUNQUEST,12,41,Performed by: Oprisiu Jessica,2014-09-10 14:07:00.000,Final result,NULL,85,50,140,mg/dL,Y,2014-09-10 14:00:00.000,2014-09-10 14:00:00.000,2014-09-10 14:07:00.000,G99999,ORDERING, GENERIC,LAB13496'

# %%
group_gt22_commas.filter(pl.col('special_cond_count') == 4).slice(0, 1).to_numpy()[0, 0]
# Out:
# '0xA21E4A754477F4D124AFC220EC87A2ED6EA8816D2DF510643421F164E41557D4,96891146,Pregnancy, urine, qualitative,35359,SUNQUEST,12,46,Although the production of HCG is extremely rapid following conception, it varies among individuals.  A negative value does not rule out pregnancy.  A serum quantitative HCG may be of clinical utility when greater assurance is required.,2014-08-15 18:28:00.000,Final result,NULL,Negative,NULL,NULL,NULL,NULL,2014-08-15 17:41:00.000,2014-08-15 17:42:00.000,2014-08-15 18:28:00.000,H31921,CHOPRA, AMIT,LAB437'

# %% [markdown]
# ### Replace all (attempt #1)

# %%
group_gt22_commas = group_gt22_commas.with_columns( 
    pl.col("row").str.replace_all("\s*,\s+|\s+,\s*", " ", literal=False)
)

# %%
group_gt22_commas = group_gt22_commas.with_columns(
    pl.col("row").str.count_matches(",", literal=True).alias("comma_count_2")
)

# %%
print(group_gt22_commas['comma_count_2'].value_counts().sort("count", descending=True).head(10))
# Out:
# shape: (10, 2)
# ┌───────────────┬─────────┐
# │ comma_count_2 ┆ count   │
# │ ---           ┆ ---     │
# │ u32           ┆ u32     │
# ╞═══════════════╪═════════╡
# │ 21            ┆ 3955103 │
# │ 20            ┆ 59430   │
# │ 22            ┆ 42438   │
# │ 23            ┆ 669     │
# │ 24            ┆ 44      │
# │ 25            ┆ 30      │
# │ 19            ┆ 9       │
# │ 26            ┆ 5       │
# │ 29            ┆ 3       │
# │ 28            ┆ 2       │
# └───────────────┴─────────┘

# %%
group_gt22_commas.filter(pl.col('comma_count_2') == 20).slice(0, 1).to_numpy()[0, 0]
# Out:
# '0x6F22E7B154E1B50658797571BA3F9BB197BB156D1D929FBB1D301E194DE30C4A,96889059,Emergency Toxicology Screen urine,64575,SUNQUEST,12,41 300 ng per ml cutoff,2014-08-16 01:21:00.000,Final result,NULL,Not detected,NULL,NULL,NULL,NULL,2014-08-15 17:29:00.000,2014-08-15 17:27:00.000,2014-08-16 01:21:00.000,H11599,FOLT JASON,LAB677'

# %%
group_gt22_commas.filter(pl.col('comma_count_2') == 22).slice(0, 1).to_numpy()[0, 0]
# Out:
# '0x58C33A0015F6CD6C32E9D8289BF8A8A1A2D4055F7C0BD109E595F1F49CB5314D,96887469,LDH,Total,840,SUNQUEST,12,41,NULL,2014-08-16 06:28:00.000,Final result,NULL,215,100,220,IU/L,Y,2014-08-16 01:00:00.000,2014-08-16 05:00:00.000,2014-08-16 06:28:00.000,H131370,BHANSALI HARDIK,LAB96'

# %%
headers = [
    "CSN_HASH", # ***
    "ORDER_ID",
    "DISPLAY_NAME",
    "PROC_ID", 
    "LAB_NAME",
    "RESULT_LAB_ID",
    "RESULTING_LAB_ID",
    "COMPONENT_COMMENT",
    "RESULT_TIME", # TIME
    "RESULT_TYPE",
    "RESULT_FLAG",
    "ORD_VALUE", # ***             
    "REFERENCE_LOW",
    "REFERENCE_HIGH",
    "REFERENCE_UNIT",
    "RESULT_IN_RANGE_Y_OR_N",
    "TEST_REQUEST_TIME",  # TIME
    "TEST_START_TIME",  # TIME
    "TEST_COMPLETE_TIME",  # TIME
    "PROVIDER_ID",
    "PHYSICIAN_LASTNAME",
    "PHYSICIAN_FIRSTNAME",
    "CPT_CODE" # ***
]

# %%
headers[-7:]
# Out:
# ['TEST_REQUEST_TIME',
#  'TEST_START_TIME',
#  'TEST_COMPLETE_TIME',
#  'PROVIDER_ID',
#  'PHYSICIAN_LASTNAME',
#  'PHYSICIAN_FIRSTNAME',
#  'CPT_CODE']

# %% [markdown]
# ### How to extract `ORD_VALUE` which is the result value?
# "Find the first datetime, slide over two commas, then you're at `ORD_VALUE`"
# ```
#     "RESULT_TIME", # TIME
#     "RESULT_TYPE",
#     "RESULT_FLAG",
#     "ORD_VALUE" # ***
# ```

# %%
group_4_dates = group_4_dates.with_columns(
    pl.col("row")
    .str.find(r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}")
    .alias("first_dt_pos")
)
group_4_dates.head()
# Out:
# shape: (5, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ row       ┆ comma_cou ┆ special_c ┆ comma_cou ┆ … ┆ TEST_REQU ┆ TEST_STAR ┆ TEST_COMP ┆ first_dt │
# │ ---       ┆ nt        ┆ ond_count ┆ nt_2      ┆   ┆ EST_TIME  ┆ T_TIME    ┆ LETE_TIME ┆ _pos     │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ u32       ┆ u32       ┆ u32       ┆   ┆ datetime[ ┆ datetime[ ┆ datetime[ ┆ u32      │
# │           ┆           ┆           ┆           ┆   ┆ μs]       ┆ μs]       ┆ μs]       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 0x6866B1E ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 133      │
# │ 321722786 ┆           ┆           ┆           ┆   ┆ 5         ┆ 5         ┆ 5         ┆          │
# │ E0C3CFBAF ┆           ┆           ┆           ┆   ┆ 17:10:00  ┆ 17:09:00  ┆ 18:49:00  ┆          │
# │ 02E…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0x6866B1E ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 133      │
# │ 321722786 ┆           ┆           ┆           ┆   ┆ 5         ┆ 5         ┆ 5         ┆          │
# │ E0C3CFBAF ┆           ┆           ┆           ┆   ┆ 17:10:00  ┆ 20:09:00  ┆ 21:59:00  ┆          │
# │ 02E…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0x3C50FD7 ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 119      │
# │ BDB88597E ┆           ┆           ┆           ┆   ┆ 5         ┆ 5         ┆ 5         ┆          │
# │ 0A426AFBC ┆           ┆           ┆           ┆   ┆ 17:01:00  ┆ 17:02:00  ┆ 17:39:00  ┆          │
# │ 3E1…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0x3C50FD7 ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 123      │
# │ BDB88597E ┆           ┆           ┆           ┆   ┆ 5         ┆ 5         ┆ 5         ┆          │
# │ 0A426AFBC ┆           ┆           ┆           ┆   ┆ 17:01:00  ┆ 17:02:00  ┆ 17:39:00  ┆          │
# │ 3E1…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0x440960B ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 2014-08-1 ┆ 116      │
# │ 54DB9F0AF ┆           ┆           ┆           ┆   ┆ 6         ┆ 6         ┆ 7         ┆          │
# │ C9A50586F ┆           ┆           ┆           ┆   ┆ 17:00:00  ┆ 21:00:00  ┆ 06:52:00  ┆          │
# │ CC8…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
mylist = group_4_dates.slice(0, 5).to_numpy()[:, 0]
[i[:133] for i in mylist]
# Out:
# ['0x6866B1E321722786E0C3CFBAF02E276B733967073B9099CC5C0D81857D37694D,96885439,Troponin I now then in 3 hours,64647,SUNQUEST,12,41,NULL,',
#  '0x6866B1E321722786E0C3CFBAF02E276B733967073B9099CC5C0D81857D37694D,96885440,Troponin I now then in 3 hours,64647,SUNQUEST,12,41,NULL,',
#  '0x3C50FD7BDB88597E0A426AFBC3E184FC15D729DFEA0741A7F7684FEF0FD95FC8,96885474,Blood Gas arterial,800,SUNQUEST,12,25,NULL,2014-08-15 17:',
#  '0x3C50FD7BDB88597E0A426AFBC3E184FC15D729DFEA0741A7F7684FEF0FD95FC8,96885475,Lactate whole blood,110329,SUNQUEST,12,25,NULL,2014-08-15',
#  '0x440960B54DB9F0AFC9A50586FCC816ABCF16B770FC7519DB70195F49421D74AE,96885637,Calcium ionized,756,SUNQUEST,12,41,NULL,2014-08-17 06:52:']

# %%
[i[133:190] for i in mylist]
# Out:
# ['2014-08-15 18:49:00.000,Final result,High,0.11,NULL,NULL,',
#  '2014-08-15 21:59:00.000,Final result,High Panic,7.73,NULL',
#  '39:00.000,Final result,Low,73.8,80,100,mmHg,NULL,2014-08-',
#  ' 17:39:00.000,Final result,NULL,1.6,0.5,2.2,mmol/L,Y,2014',
#  '00.000,Final result,NULL,1.14,1.00,1.35,mmol/L,Y,2014-08-']

# %% [markdown]
# We want to extract `0.11`, `7.73`, `73.8`, `1.6`, and `1.14`, respectively.

# %%
group_4_dates = group_4_dates.with_columns(
    pl.col('row')
    .str.slice(pl.col("first_dt_pos"))
    .str.splitn(",", 5)
    .struct.rename_fields(["RESULT_TIME_1", "RESULT_TYPE", "RESULT_FLAG", "ORD_VALUE", "OTHER"])
    .alias("t_break")
).unnest("t_break")

group_4_dates = group_4_dates.drop(["RESULT_TIME_1", "RESULT_TYPE", "RESULT_FLAG", "OTHER"])

group_4_dates.head()
# Out:
# shape: (5, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ row       ┆ comma_cou ┆ special_c ┆ comma_cou ┆ … ┆ TEST_STAR ┆ TEST_COMP ┆ first_dt_ ┆ ORD_VALU │
# │ ---       ┆ nt        ┆ ond_count ┆ nt_2      ┆   ┆ T_TIME    ┆ LETE_TIME ┆ pos       ┆ E        │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ u32       ┆ u32       ┆ u32       ┆   ┆ datetime[ ┆ datetime[ ┆ u32       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ μs]       ┆ μs]       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 0x6866B1E ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 133       ┆ 0.11     │
# │ 321722786 ┆           ┆           ┆           ┆   ┆ 5         ┆ 5         ┆           ┆          │
# │ E0C3CFBAF ┆           ┆           ┆           ┆   ┆ 17:09:00  ┆ 18:49:00  ┆           ┆          │
# │ 02E…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0x6866B1E ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 133       ┆ 7.73     │
# │ 321722786 ┆           ┆           ┆           ┆   ┆ 5         ┆ 5         ┆           ┆          │
# │ E0C3CFBAF ┆           ┆           ┆           ┆   ┆ 20:09:00  ┆ 21:59:00  ┆           ┆          │
# │ 02E…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0x3C50FD7 ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 119       ┆ 73.8     │
# │ BDB88597E ┆           ┆           ┆           ┆   ┆ 5         ┆ 5         ┆           ┆          │
# │ 0A426AFBC ┆           ┆           ┆           ┆   ┆ 17:02:00  ┆ 17:39:00  ┆           ┆          │
# │ 3E1…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0x3C50FD7 ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 123       ┆ 1.6      │
# │ BDB88597E ┆           ┆           ┆           ┆   ┆ 5         ┆ 5         ┆           ┆          │
# │ 0A426AFBC ┆           ┆           ┆           ┆   ┆ 17:02:00  ┆ 17:39:00  ┆           ┆          │
# │ 3E1…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0x440960B ┆ 23        ┆ 2         ┆ 21        ┆ … ┆ 2014-08-1 ┆ 2014-08-1 ┆ 116       ┆ 1.14     │
# │ 54DB9F0AF ┆           ┆           ┆           ┆   ┆ 6         ┆ 7         ┆           ┆          │
# │ C9A50586F ┆           ┆           ┆           ┆   ┆ 21:00:00  ┆ 06:52:00  ┆           ┆          │
# │ CC8…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
assert group_4_dates["ORD_VALUE"].null_count() == 0

# %%
group_4_dates.shape[0], group_4_dates["ORD_VALUE"].n_unique()
# Out:
# (3045085, 27638)

# %%
# Out:
# 0.9379964762888392
